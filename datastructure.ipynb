# %% [markdown]
# ## data structure
# - 1-tuple
# - 2-list
# - 3-dictionary
# - 4-set

# %% [markdown]
# ## tuples
# - orderd collection of elements
# - different kind of element can be stored
# - enclosed in ()
# - once element stored you cannot change it

# %%
tup1=(1,"tayyab", True)
tup1=tup1+tup1
tup1
# Out:
# (1, 'tayyab', True, 1, 'tayyab', True)

# %%
tup1[3]
# Out:
# 1

# %%
tup2=(4,"zahid",False)
len(tup2)
# Out:
# 3

# %% [markdown]
# ## List
# - ordered collection of elements
# - enclosed in sequare bractes []
# - mutatable we can change the value

# %%
list1=[1,"hamza","khalid",35]
list2=[2,tup2[1],"farhan",33]
type(list1)
list1+list2
# Out:
# [1, 'hamza', 'khalid', 35, 2, 'zahid', 'farhan', 33]

# %%
list1
# Out:
# [1, 'hamza', 'khalid', 35]

# %%
list1.append(45)
list1
# Out:
# [1, 'hamza', 'khalid', 35, 45]

# %% [markdown]
# ## dictionary
# - an unorderd collection
# - key and values
# - curely brackets
# - mutatable changeable

# %%
dic={"t":"tayyab",5:55,}
dic.keys()
# Out:
# dict_keys(['t', 5])

# %%
dic["h"]="hamza"
dic
# Out:
# {'t': 'tayyab', 5: 55, 'h': 'hamza'}

# %%
dic.update({"g":"gujjar"})
dic
# Out:
# {'t': 'tayyab', 5: 55, 'h': 'hamza', 'g': 'gujjar'}

# %% [markdown]
# ## set
# - unordered and unindexed
# -  curly brackets
# - no duplicate

# %%
s1={1,2,3,4,"ali","lahore"}
s1
# Out:
# {1, 2, 3, 4, 'ali', 'lahore'}

# %%
s1.add("ali1")
s1
# Out:
# {1, 2, 3, 4, 'ali', 'ali1', 'lahore'}
