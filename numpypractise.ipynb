# %% [markdown]
# ## numpy
# - numaric pythone
# - operate big data operation
# - same like lists
# - much faster then list
# - consume less memory
# - work on same datatype
# - vector(single dim array) matriz( double dimension array)

# %%
# create an arry
import numpy as np

food=np.array(["vegi","naaan","meat"])
food[1]
# Out:
# 'naaan'
